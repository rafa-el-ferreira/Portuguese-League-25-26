# %% [markdown]
# <a href="https://colab.research.google.com/github/rafa-el-ferreira/Portuguese-League-25-26/blob/main/Task_M10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1st METRIC** **MAIN** **CODE**

# %%
#first install pandas
import pandas as pd

#Then do the Plain Request
import requests
import json

#import json_normalize()
from pandas import json_normalize

#Explore competitions
uri = 'https://api.football-data.org/v4/competitions/'
my_key = { 'X-Auth-Token': '7972cc960161452182712a662c532115' }

response = requests.get(uri, headers=my_key)

competitions = response.json()


#now this is the full request
competitions_final = json_normalize(competitions["competitions"])

# %% [markdown]
# **STARTING TO PEEL THE ONION**

# %%
#Now i'll try to get more info
type(competitions) #dictionary
competitions.keys()
# Out:
# dict_keys(['count', 'filters', 'competitions'])

# %%
#Check what's inside each key and after that explore it
competitions["competitions"]
# Out:
# [{'id': 2013,
#   'area': {'id': 2032,
#    'name': 'Brazil',
#    'code': 'BRA',
#    'flag': 'https://crests.football-data.org/764.svg'},
#   'name': 'Campeonato Brasileiro Série A',
#   'code': 'BSA',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/bsa.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2474,
#    'startDate': '2026-01-28',
#    'endDate': '2026-12-02',
#    'currentMatchday': 17,
#    'winner': None},
#   'numberOfAvailableSeasons': 10,
#   'lastUpdated': '2024-09-13T16:55:53Z'},
#  {'id': 2016,
#   'area': {'id': 2072,
#    'name': 'England',
#    'code': 'ENG',
#    'flag': 'https://crests.football-data.org/770.svg'},
#   'name': 'Championship',
#   'code': 'ELC',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/ELC.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2416,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-12',
#    'currentMatchday': 46,
#    'winner': None},
#   'numberOfAvailableSeasons': 9,
#   'lastUpdated': '2026-05-11T15:45:39Z'},
#  {'id': 2021,
#   'area': {'id': 2072,
#    'name': 'England',
#    'code': 'ENG',
#    'flag': 'https://crests.football-data.org/770.svg'},
#   'name': 'Premier League',
#   'code': 'PL',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/PL.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2403,
#    'startDate': '2025-08-15',
#    'endDate': '2026-05-24',
#    'currentMatchday': 38,
#    'winner': None},
#   'numberOfAvailableSeasons': 127,
#   'lastUpdated': '2024-09-13T16:51:24Z'},
#  {'id': 2001,
#   'area': {'id': 2077,
#    'name': 'Europe',
#    'code': 'EUR',
#    'flag': 'https://crests.football-data.org/EUR.svg'},
#   'name': 'UEFA Champions League',
#   'code': 'CL',
#   'type': 'CUP',
#   'emblem': 'https://crests.football-data.org/CL.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2454,
#    'startDate': '2025-09-16',
#    'endDate': '2026-05-30',
#    'currentMatchday': 8,
#    'winner': None},
#   'numberOfAvailableSeasons': 46,
#   'lastUpdated': '2024-09-13T16:53:48Z'},
#  {'id': 2018,
#   'area': {'id': 2077,
#    'name': 'Europe',
#    'code': 'EUR',
#    'flag': 'https://crests.football-data.org/EUR.svg'},
#   'name': 'European Championship',
#   'code': 'EC',
#   'type': 'CUP',
#   'emblem': 'https://crests.football-data.org/ec.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 1537,
#    'startDate': '2024-06-14',
#    'endDate': '2024-07-14',
#    'currentMatchday': 7,
#    'winner': {'id': 760,
#     'name': 'Spain',
#     'shortName': 'Spain',
#     'tla': 'ESP',
#     'crest': 'https://crests.football-data.org/760.svg',
#     'address': 'Ramón y Cajal, s/n Las Rozas 28230',
#     'website': 'http://www.rfef.es',
#     'founded': 1909,
#     'clubColors': 'Red / Blue / Yellow',
#     'venue': 'Estadio Alfredo Di Stéfano',
#     'lastUpdated': '2021-05-26T09:46:48Z'}},
#   'numberOfAvailableSeasons': 17,
#   'lastUpdated': '2024-09-13T17:04:30Z'},
#  {'id': 2015,
#   'area': {'id': 2081,
#    'name': 'France',
#    'code': 'FRA',
#    'flag': 'https://crests.football-data.org/773.svg'},
#   'name': 'Ligue 1',
#   'code': 'FL1',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/FL1.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2420,
#    'startDate': '2025-08-17',
#    'endDate': '2026-05-16',
#    'currentMatchday': 33,
#    'winner': None},
#   'numberOfAvailableSeasons': 82,
#   'lastUpdated': '2024-09-13T16:49:18Z'},
#  {'id': 2002,
#   'area': {'id': 2088,
#    'name': 'Germany',
#    'code': 'DEU',
#    'flag': 'https://crests.football-data.org/759.svg'},
#   'name': 'Bundesliga',
#   'code': 'BL1',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/BL1.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2414,
#    'startDate': '2025-08-22',
#    'endDate': '2026-05-16',
#    'currentMatchday': 34,
#    'winner': None},
#   'numberOfAvailableSeasons': 63,
#   'lastUpdated': '2024-09-13T16:48:00Z'},
#  {'id': 2019,
#   'area': {'id': 2114,
#    'name': 'Italy',
#    'code': 'ITA',
#    'flag': 'https://crests.football-data.org/784.svg'},
#   'name': 'Serie A',
#   'code': 'SA',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/c111.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2395,
#    'startDate': '2025-08-24',
#    'endDate': '2026-05-24',
#    'currentMatchday': 38,
#    'winner': None},
#   'numberOfAvailableSeasons': 94,
#   'lastUpdated': '2026-01-02T11:22:51Z'},
#  {'id': 2003,
#   'area': {'id': 2163,
#    'name': 'Netherlands',
#    'code': 'NLD',
#    'flag': 'https://crests.football-data.org/8601.svg'},
#   'name': 'Eredivisie',
#   'code': 'DED',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/ED.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2400,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'numberOfAvailableSeasons': 70,
#   'lastUpdated': '2024-09-13T16:34:42Z'},
#  {'id': 2017,
#   'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'name': 'Primeira Liga',
#   'code': 'PPL',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/PPL.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'numberOfAvailableSeasons': 77,
#   'lastUpdated': '2024-09-13T16:54:08Z'},
#  {'id': 2152,
#   'area': {'id': 2220,
#    'name': 'South America',
#    'code': 'SAM',
#    'flag': 'https://crests.football-data.org/CLI.svg'},
#   'name': 'Copa Libertadores',
#   'code': 'CLI',
#   'type': 'CUP',
#   'emblem': 'https://crests.football-data.org/CLI.svg',
#   'plan': 'TIER_FOUR',
#   'currentSeason': {'id': 2466,
#    'startDate': '2026-02-04',
#    'endDate': '2026-11-28',
#    'currentMatchday': 6,
#    'winner': None},
#   'numberOfAvailableSeasons': 6,
#   'lastUpdated': '2026-05-20T00:07:05Z'},
#  {'id': 2014,
#   'area': {'id': 2224,
#    'name': 'Spain',
#    'code': 'ESP',
#    'flag': 'https://crests.football-data.org/760.svg'},
#   'name': 'Primera Division',
#   'code': 'PD',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/laliga.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2429,
#    'startDate': '2025-08-17',
#    'endDate': '2026-05-24',
#    'currentMatchday': 38,
#    'winner': None},
#   'numberOfAvailableSeasons': 94,
#   'lastUpdated': '2024-09-13T16:52:33Z'},
#  {'id': 2000,
#   'area': {'id': 2267, 'name': 'World', 'code': 'INT', 'flag': None},
#   'name': 'FIFA World Cup',
#   'code': 'WC',
#   'type': 'CUP',
#   'emblem': 'https://crests.football-data.org/wm26.png',
#   'plan': 'TIER_ONE',
#   'currentSeason': {'id': 2398,
#    'startDate': '2026-06-11',
#    'endDate': '2026-07-19',
#    'currentMatchday': 1,
#    'winner': None},
#   'numberOfAvailableSeasons': 23,
#   'lastUpdated': '2025-12-08T05:32:32Z'}]

# %%
type(competitions["competitions"])
# Out:
# list

# %%
len(competitions["competitions"])
# Out:
# 13

# %%
#see what's inside some index and can confirme each index corresponds a league
competitions["competitions"][1]
# Out:
# {'id': 2016,
#  'area': {'id': 2072,
#   'name': 'England',
#   'code': 'ENG',
#   'flag': 'https://crests.football-data.org/770.svg'},
#  'name': 'Championship',
#  'code': 'ELC',
#  'type': 'LEAGUE',
#  'emblem': 'https://crests.football-data.org/ELC.png',
#  'plan': 'TIER_ONE',
#  'currentSeason': {'id': 2416,
#   'startDate': '2025-08-08',
#   'endDate': '2026-05-12',
#   'currentMatchday': 46,
#   'winner': None},
#  'numberOfAvailableSeasons': 9,
#  'lastUpdated': '2026-05-11T15:45:39Z'}

# %% [markdown]
# No more onion to peel

# %%
#Now we use json_normalize to transform this list of dictionaries into a DataFrame to work it
#go back to MAIN CODE and write:
#from pandas import json_normalize
#competitions_final = json_normalize(competitions["competitions"])

# %%
competitions_final
# Out:
#       id                           name code    type  \
# 0   2013  Campeonato Brasileiro Série A  BSA  LEAGUE
# 1   2016                   Championship  ELC  LEAGUE
# 2   2021                 Premier League   PL  LEAGUE
# 3   2001          UEFA Champions League   CL     CUP
# 4   2018          European Championship   EC     CUP
# 5   2015                        Ligue 1  FL1  LEAGUE
# 6   2002                     Bundesliga  BL1  LEAGUE
# 7   2019                        Serie A   SA  LEAGUE
# 8   2003                     Eredivisie  DED  LEAGUE
# 9   2017                  Primeira Liga  PPL  LEAGUE
# 10  2152              Copa Libertadores  CLI     CUP
# 11  2014               Primera Division   PD  LEAGUE
# 12  2000                 FIFA World Cup   WC     CUP
#
#                                          emblem       plan  \
# 0      https://crests.football-data.org/bsa.png   TIER_ONE
# 1      https://crests.football-data.org/ELC.png   TIER_ONE
# 2       https://crests.football-data.org/PL.png   TIER_ONE
# 3       https://crests.football-data.org/CL.png   TIER_ONE
# 4       https://crests.football-data.org/ec.png   TIER_ONE
# 5      https://crests.football-data.org/FL1.png   TIER_ONE
# 6      https://crests.football-data.org/BL1.png   TIER_ONE
# 7     https://crests.football-data.org/c111.png   TIER_ONE
# 8       https://crests.football-data.org/ED.png   TIER_ONE
# 9      https://crests.football-data.org/PPL.png   TIER_ONE
# 10     https://crests.football-data.org/CLI.svg  TIER_FOUR
# 11  https://crests.football-data.org/laliga.png   TIER_ONE
# 12    https://crests.football-data.org/wm26.png   TIER_ONE
#
#     numberOfAvailableSeasons           lastUpdated  area.id      area.name  \
# 0                         10  2024-09-13T16:55:53Z     2032         Brazil
# 1                          9  2026-05-11T15:45:39Z     2072        England
# 2                        127  2024-09-13T16:51:24Z     2072        England
# 3                         46  2024-09-13T16:53:48Z     2077         Europe
# 4                         17  2024-09-13T17:04:30Z     2077         Europe
# 5                         82  2024-09-13T16:49:18Z     2081         France
# 6                         63  2024-09-13T16:48:00Z     2088        Germany
# 7                         94  2026-01-02T11:22:51Z     2114          Italy
# 8                         70  2024-09-13T16:34:42Z     2163    Netherlands
# 9                         77  2024-09-13T16:54:08Z     2187       Portugal
# 10                         6  2026-05-20T00:07:05Z     2220  South America
# 11                        94  2024-09-13T16:52:33Z     2224          Spain
# 12                        23  2025-12-08T05:32:32Z     2267          World
#
#     ... currentSeason.winner.name currentSeason.winner.shortName  \
# 0   ...                       NaN                            NaN
# 1   ...                       NaN                            NaN
# 2   ...                       NaN                            NaN
# 3   ...                       NaN                            NaN
# 4   ...                     Spain                          Spain
# 5   ...                       NaN                            NaN
# 6   ...                       NaN                            NaN
# 7   ...                       NaN                            NaN
# 8   ...                       NaN                            NaN
# 9   ...                       NaN                            NaN
# 10  ...                       NaN                            NaN
# 11  ...                       NaN                            NaN
# 12  ...                       NaN                            NaN
#
#     currentSeason.winner.tla                currentSeason.winner.crest  \
# 0                        NaN                                       NaN
# 1                        NaN                                       NaN
# 2                        NaN                                       NaN
# 3                        NaN                                       NaN
# 4                        ESP  https://crests.football-data.org/760.svg
# 5                        NaN                                       NaN
# 6                        NaN                                       NaN
# 7                        NaN                                       NaN
# 8                        NaN                                       NaN
# 9                        NaN                                       NaN
# 10                       NaN                                       NaN
# 11                       NaN                                       NaN
# 12                       NaN                                       NaN
#
#           currentSeason.winner.address  currentSeason.winner.website  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4   Ramón y Cajal, s/n Las Rozas 28230            http://www.rfef.es
# 5                                  NaN                           NaN
# 6                                  NaN                           NaN
# 7                                  NaN                           NaN
# 8                                  NaN                           NaN
# 9                                  NaN                           NaN
# 10                                 NaN                           NaN
# 11                                 NaN                           NaN
# 12                                 NaN                           NaN
#
#     currentSeason.winner.founded  currentSeason.winner.clubColors  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                         1909.0              Red / Blue / Yellow
# 5                            NaN                              NaN
# 6                            NaN                              NaN
# 7                            NaN                              NaN
# 8                            NaN                              NaN
# 9                            NaN                              NaN
# 10                           NaN                              NaN
# 11                           NaN                              NaN
# 12                           NaN                              NaN
#
#     currentSeason.winner.venue currentSeason.winner.lastUpdated
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4   Estadio Alfredo Di Stéfano             2021-05-26T09:46:48Z
# 5                          NaN                              NaN
# 6                          NaN                              NaN
# 7                          NaN                              NaN
# 8                          NaN                              NaN
# 9                          NaN                              NaN
# 10                         NaN                              NaN
# 11                         NaN                              NaN
# 12                         NaN                              NaN
#
# [13 rows x 28 columns]

# %%
type(competitions_final)
# Out:
# pandas.core.frame.DataFrame

# %%
#we can see that this is a DataFrame, so here are some functions to explore it
competitions_final.head()
competitions_final.tail()
competitions_final.sample(3)
competitions_final.info() #a very important one to check if the Dtype is ok and if there are non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                13 non-null     int64
#  1   name                              13 non-null     object
#  2   code                              13 non-null     object
#  3   type                              13 non-null     object
#  4   emblem                            13 non-null     object
#  5   plan                              13 non-null     object
#  6   numberOfAvailableSeasons          13 non-null     int64
#  7   lastUpdated                       13 non-null     object
#  8   area.id                           13 non-null     int64
#  9   area.name                         13 non-null     object
#  10  area.code                         13 non-null     object
#  11  area.flag                         12 non-null     object
#  12  currentSeason.id                  13 non-null     int64
#  13  currentSeason.startDate           13 non-null     object
#  14  currentSeason.endDate             13 non-null     object
#  15  currentSeason.currentMatchday     13 non-null     int64
#  16  currentSeason.winner              0 non-null      float64
#  17  currentSeason.winner.id           1 non-null      float64
#  18  currentSeason.winner.name         1 non-null      object
#  19  currentSeason.winner.shortName    1 non-null      object
#  20  currentSeason.winner.tla          1 non-null      object
#  21  currentSeason.winner.crest        1 non-null      object
#  22  currentSeason.winner.address      1 non-null      object
#  23  currentSeason.winner.website      1 non-null      object
#  24  currentSeason.winner.founded      1 non-null      float64
#  25  currentSeason.winner.clubColors   1 non-null      object
#  26  currentSeason.winner.venue        1 non-null      object
#  27  currentSeason.winner.lastUpdated  1 non-null      object
# dtypes: float64(3), int64(5), object(20)
# memory usage: 3.0+ KB

# %% [markdown]
# PORTUGUESE LEAGUE MATCHES MAIN CODE

# %%
uri = 'https://api.football-data.org/v4/competitions/PPL/matches'
my_key = { 'X-Auth-Token': '7972cc960161452182712a662c532115' }

response = requests.get(uri, headers=my_key)

matches = response.json()

PPL_matches = json_normalize(matches["matches"])

# %%
type(matches)
# Out:
# dict

# %%
matches.keys()
# Out:
# dict_keys(['filters', 'resultSet', 'competition', 'matches'])

# %%
matches["matches"] #this is the information that we want and now we'll do the same process before
# Out:
# [{'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545700,
#   'utcDate': '2025-08-08T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 1,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 6618,
#    'name': 'Casa Pia AC',
#    'shortName': 'Casa Pia',
#    'tla': 'CAS',
#    'crest': 'https://crests.football-data.org/6618.png'},
#   'awayTeam': {'id': 498,
#    'name': 'Sporting Clube de Portugal',
#    'shortName': 'Sporting CP',
#    'tla': 'SPO',
#    'crest': 'https://crests.football-data.org/498.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 2},
#    'halfTime': {'home': 0, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545706,
#   'utcDate': '2025-08-09T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 1,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5529,
#    'name': 'CD Nacional',
#    'shortName': 'CD Nacional',
#    'tla': 'CDN',
#    'crest': 'https://crests.football-data.org/5529.png'},
#   'awayTeam': {'id': 5533,
#    'name': 'Gil Vicente FC',
#    'shortName': 'Gil Vicente',
#    'tla': 'GIL',
#    'crest': 'https://crests.football-data.org/5533.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 2},
#    'halfTime': {'home': 0, 'away': 2}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545703,
#   'utcDate': '2025-08-09T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 1,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 712,
#    'name': 'FC Arouca',
#    'shortName': 'Arouca',
#    'tla': 'FCA',
#    'crest': 'https://crests.football-data.org/712.png'},
#   'awayTeam': {'id': 10340,
#    'name': 'AVS',
#    'shortName': 'AVS',
#    'tla': 'AVS',
#    'crest': 'https://crests.football-data.org/10340.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 1},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545707,
#   'utcDate': '2025-08-10T16:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 1,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5531,
#    'name': 'FC Famalicão',
#    'shortName': 'Famalicão',
#    'tla': 'FAM',
#    'crest': 'https://crests.football-data.org/5531.png'},
#   'awayTeam': {'id': 5530,
#    'name': 'CD Santa Clara',
#    'shortName': 'Santa Clara',
#    'tla': 'CD ',
#    'crest': 'https://crests.football-data.org/5530.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 0},
#    'halfTime': {'home': 2, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545701,
#   'utcDate': '2025-08-10T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 1,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5613,
#    'name': 'Sporting Clube de Braga',
#    'shortName': 'Braga',
#    'tla': 'SCB',
#    'crest': 'https://crests.football-data.org/5613.png'},
#   'awayTeam': {'id': 1049,
#    'name': 'CD Tondela',
#    'shortName': 'Tondela',
#    'tla': 'TON',
#    'crest': 'https://crests.football-data.org/1049.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 0},
#    'halfTime': {'home': 2, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545705,
#   'utcDate': '2025-08-10T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 1,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 583,
#    'name': 'Moreirense FC',
#    'shortName': 'Moreirense',
#    'tla': 'MOR',
#    'crest': 'https://crests.football-data.org/583.png'},
#   'awayTeam': {'id': 7822,
#    'name': 'FC Alverca',
#    'shortName': 'Alverca',
#    'tla': 'ALV',
#    'crest': 'https://crests.football-data.org/7822.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 1},
#    'halfTime': {'home': 1, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545704,
#   'utcDate': '2025-08-11T17:45:00Z',
#   'status': 'FINISHED',
#   'matchday': 1,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 582,
#    'name': 'GD Estoril Praia',
#    'shortName': 'Estoril Praia',
#    'tla': 'EST',
#    'crest': 'https://crests.football-data.org/582.png'},
#   'awayTeam': {'id': 9136,
#    'name': 'CF Estrela da Amadora',
#    'shortName': 'Amadora',
#    'tla': 'AMA',
#    'crest': 'https://crests.football-data.org/9136.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 1},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545708,
#   'utcDate': '2025-08-11T19:45:00Z',
#   'status': 'FINISHED',
#   'matchday': 1,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 503,
#    'name': 'FC Porto',
#    'shortName': 'Porto',
#    'tla': 'FCP',
#    'crest': 'https://crests.football-data.org/503.png'},
#   'awayTeam': {'id': 5543,
#    'name': 'Vitória SC',
#    'shortName': 'Vitória SC',
#    'tla': 'GUI',
#    'crest': 'https://crests.football-data.org/5543.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 0},
#    'halfTime': {'home': 2, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545709,
#   'utcDate': '2025-08-15T14:45:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 10340,
#    'name': 'AVS',
#    'shortName': 'AVS',
#    'tla': 'AVS',
#    'crest': 'https://crests.football-data.org/10340.png'},
#   'awayTeam': {'id': 6618,
#    'name': 'Casa Pia AC',
#    'shortName': 'Casa Pia',
#    'tla': 'CAS',
#    'crest': 'https://crests.football-data.org/6618.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 2},
#    'halfTime': {'home': 0, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545716,
#   'utcDate': '2025-08-16T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 1049,
#    'name': 'CD Tondela',
#    'shortName': 'Tondela',
#    'tla': 'TON',
#    'crest': 'https://crests.football-data.org/1049.png'},
#   'awayTeam': {'id': 5531,
#    'name': 'FC Famalicão',
#    'shortName': 'Famalicão',
#    'tla': 'FAM',
#    'crest': 'https://crests.football-data.org/5531.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 1},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545714,
#   'utcDate': '2025-08-16T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5543,
#    'name': 'Vitória SC',
#    'shortName': 'Vitória SC',
#    'tla': 'GUI',
#    'crest': 'https://crests.football-data.org/5543.png'},
#   'awayTeam': {'id': 582,
#    'name': 'GD Estoril Praia',
#    'shortName': 'Estoril Praia',
#    'tla': 'EST',
#    'crest': 'https://crests.football-data.org/582.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 2},
#    'halfTime': {'home': 1, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545717,
#   'utcDate': '2025-08-16T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 9136,
#    'name': 'CF Estrela da Amadora',
#    'shortName': 'Amadora',
#    'tla': 'AMA',
#    'crest': 'https://crests.football-data.org/9136.png'},
#   'awayTeam': {'id': 1903,
#    'name': 'Sport Lisboa e Benfica',
#    'shortName': 'SL Benfica',
#    'tla': 'BEN',
#    'crest': 'https://crests.football-data.org/1903.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 1},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545713,
#   'utcDate': '2025-08-17T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 496,
#    'name': 'Rio Ave FC',
#    'shortName': 'Rio Ave',
#    'tla': 'RIO',
#    'crest': 'https://crests.football-data.org/496.png'},
#   'awayTeam': {'id': 5529,
#    'name': 'CD Nacional',
#    'shortName': 'CD Nacional',
#    'tla': 'CDN',
#    'crest': 'https://crests.football-data.org/5529.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 1},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545710,
#   'utcDate': '2025-08-17T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 7822,
#    'name': 'FC Alverca',
#    'shortName': 'Alverca',
#    'tla': 'ALV',
#    'crest': 'https://crests.football-data.org/7822.png'},
#   'awayTeam': {'id': 5613,
#    'name': 'Sporting Clube de Braga',
#    'shortName': 'Braga',
#    'tla': 'SCB',
#    'crest': 'https://crests.football-data.org/5613.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 3},
#    'halfTime': {'home': 0, 'away': 3}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545712,
#   'utcDate': '2025-08-17T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5530,
#    'name': 'CD Santa Clara',
#    'shortName': 'Santa Clara',
#    'tla': 'CD ',
#    'crest': 'https://crests.football-data.org/5530.png'},
#   'awayTeam': {'id': 583,
#    'name': 'Moreirense FC',
#    'shortName': 'Moreirense',
#    'tla': 'MOR',
#    'crest': 'https://crests.football-data.org/583.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 1},
#    'halfTime': {'home': 0, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545715,
#   'utcDate': '2025-08-17T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 498,
#    'name': 'Sporting Clube de Portugal',
#    'shortName': 'Sporting CP',
#    'tla': 'SPO',
#    'crest': 'https://crests.football-data.org/498.png'},
#   'awayTeam': {'id': 712,
#    'name': 'FC Arouca',
#    'shortName': 'Arouca',
#    'tla': 'FCA',
#    'crest': 'https://crests.football-data.org/712.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 6, 'away': 0},
#    'halfTime': {'home': 3, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545711,
#   'utcDate': '2025-08-18T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 2,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5533,
#    'name': 'Gil Vicente FC',
#    'shortName': 'Gil Vicente',
#    'tla': 'GIL',
#    'crest': 'https://crests.football-data.org/5533.png'},
#   'awayTeam': {'id': 503,
#    'name': 'FC Porto',
#    'shortName': 'Porto',
#    'tla': 'FCP',
#    'crest': 'https://crests.football-data.org/503.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 2},
#    'halfTime': {'home': 0, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545726,
#   'utcDate': '2025-08-23T15:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 583,
#    'name': 'Moreirense FC',
#    'shortName': 'Moreirense',
#    'tla': 'MOR',
#    'crest': 'https://crests.football-data.org/583.png'},
#   'awayTeam': {'id': 5543,
#    'name': 'Vitória SC',
#    'shortName': 'Vitória SC',
#    'tla': 'GUI',
#    'crest': 'https://crests.football-data.org/5543.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545718,
#   'utcDate': '2025-08-23T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5529,
#    'name': 'CD Nacional',
#    'shortName': 'CD Nacional',
#    'tla': 'CDN',
#    'crest': 'https://crests.football-data.org/5529.png'},
#   'awayTeam': {'id': 498,
#    'name': 'Sporting Clube de Portugal',
#    'shortName': 'Sporting CP',
#    'tla': 'SPO',
#    'crest': 'https://crests.football-data.org/498.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 4},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545719,
#   'utcDate': '2025-08-23T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 712,
#    'name': 'FC Arouca',
#    'shortName': 'Arouca',
#    'tla': 'FCA',
#    'crest': 'https://crests.football-data.org/712.png'},
#   'awayTeam': {'id': 496,
#    'name': 'Rio Ave FC',
#    'shortName': 'Rio Ave',
#    'tla': 'RIO',
#    'crest': 'https://crests.football-data.org/496.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 3},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545721,
#   'utcDate': '2025-08-23T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 1903,
#    'name': 'Sport Lisboa e Benfica',
#    'shortName': 'SL Benfica',
#    'tla': 'BEN',
#    'crest': 'https://crests.football-data.org/1903.png'},
#   'awayTeam': {'id': 1049,
#    'name': 'CD Tondela',
#    'shortName': 'Tondela',
#    'tla': 'TON',
#    'crest': 'https://crests.football-data.org/1049.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 0},
#    'halfTime': {'home': 2, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545720,
#   'utcDate': '2025-08-24T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5531,
#    'name': 'FC Famalicão',
#    'shortName': 'Famalicão',
#    'tla': 'FAM',
#    'crest': 'https://crests.football-data.org/5531.png'},
#   'awayTeam': {'id': 5533,
#    'name': 'Gil Vicente FC',
#    'shortName': 'Gil Vicente',
#    'tla': 'GIL',
#    'crest': 'https://crests.football-data.org/5533.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545723,
#   'utcDate': '2025-08-24T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 503,
#    'name': 'FC Porto',
#    'shortName': 'Porto',
#    'tla': 'FCP',
#    'crest': 'https://crests.football-data.org/503.png'},
#   'awayTeam': {'id': 6618,
#    'name': 'Casa Pia AC',
#    'shortName': 'Casa Pia',
#    'tla': 'CAS',
#    'crest': 'https://crests.football-data.org/6618.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 4, 'away': 0},
#    'halfTime': {'home': 3, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545722,
#   'utcDate': '2025-08-24T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5613,
#    'name': 'Sporting Clube de Braga',
#    'shortName': 'Braga',
#    'tla': 'SCB',
#    'crest': 'https://crests.football-data.org/5613.png'},
#   'awayTeam': {'id': 10340,
#    'name': 'AVS',
#    'shortName': 'AVS',
#    'tla': 'AVS',
#    'crest': 'https://crests.football-data.org/10340.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 2},
#    'halfTime': {'home': 1, 'away': 2}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545724,
#   'utcDate': '2025-08-25T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 9136,
#    'name': 'CF Estrela da Amadora',
#    'shortName': 'Amadora',
#    'tla': 'AMA',
#    'crest': 'https://crests.football-data.org/9136.png'},
#   'awayTeam': {'id': 7822,
#    'name': 'FC Alverca',
#    'shortName': 'Alverca',
#    'tla': 'ALV',
#    'crest': 'https://crests.football-data.org/7822.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 2},
#    'halfTime': {'home': 1, 'away': 2}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545730,
#   'utcDate': '2025-08-29T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5533,
#    'name': 'Gil Vicente FC',
#    'shortName': 'Gil Vicente',
#    'tla': 'GIL',
#    'crest': 'https://crests.football-data.org/5533.png'},
#   'awayTeam': {'id': 583,
#    'name': 'Moreirense FC',
#    'shortName': 'Moreirense',
#    'tla': 'MOR',
#    'crest': 'https://crests.football-data.org/583.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545728,
#   'utcDate': '2025-08-30T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 6618,
#    'name': 'Casa Pia AC',
#    'shortName': 'Casa Pia',
#    'tla': 'CAS',
#    'crest': 'https://crests.football-data.org/6618.png'},
#   'awayTeam': {'id': 5529,
#    'name': 'CD Nacional',
#    'shortName': 'CD Nacional',
#    'tla': 'CDN',
#    'crest': 'https://crests.football-data.org/5529.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 2},
#    'halfTime': {'home': 0, 'away': 2}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545727,
#   'utcDate': '2025-08-30T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 10340,
#    'name': 'AVS',
#    'shortName': 'AVS',
#    'tla': 'AVS',
#    'crest': 'https://crests.football-data.org/10340.png'},
#   'awayTeam': {'id': 5531,
#    'name': 'FC Famalicão',
#    'shortName': 'Famalicão',
#    'tla': 'FAM',
#    'crest': 'https://crests.football-data.org/5531.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 1},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545733,
#   'utcDate': '2025-08-30T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5543,
#    'name': 'Vitória SC',
#    'shortName': 'Vitória SC',
#    'tla': 'GUI',
#    'crest': 'https://crests.football-data.org/5543.png'},
#   'awayTeam': {'id': 712,
#    'name': 'FC Arouca',
#    'shortName': 'Arouca',
#    'tla': 'FCA',
#    'crest': 'https://crests.football-data.org/712.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 1},
#    'halfTime': {'home': 1, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545734,
#   'utcDate': '2025-08-30T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 498,
#    'name': 'Sporting Clube de Portugal',
#    'shortName': 'Sporting CP',
#    'tla': 'SPO',
#    'crest': 'https://crests.football-data.org/498.png'},
#   'awayTeam': {'id': 503,
#    'name': 'FC Porto',
#    'shortName': 'Porto',
#    'tla': 'FCP',
#    'crest': 'https://crests.football-data.org/503.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 2},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545732,
#   'utcDate': '2025-08-31T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 1049,
#    'name': 'CD Tondela',
#    'shortName': 'Tondela',
#    'tla': 'TON',
#    'crest': 'https://crests.football-data.org/1049.png'},
#   'awayTeam': {'id': 582,
#    'name': 'GD Estoril Praia',
#    'shortName': 'Estoril Praia',
#    'tla': 'EST',
#    'crest': 'https://crests.football-data.org/582.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 2},
#    'halfTime': {'home': 0, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545729,
#   'utcDate': '2025-08-31T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 7822,
#    'name': 'FC Alverca',
#    'shortName': 'Alverca',
#    'tla': 'ALV',
#    'crest': 'https://crests.football-data.org/7822.png'},
#   'awayTeam': {'id': 1903,
#    'name': 'Sport Lisboa e Benfica',
#    'shortName': 'SL Benfica',
#    'tla': 'BEN',
#    'crest': 'https://crests.football-data.org/1903.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 2},
#    'halfTime': {'home': 0, 'away': 2}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545731,
#   'utcDate': '2025-08-31T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5530,
#    'name': 'CD Santa Clara',
#    'shortName': 'Santa Clara',
#    'tla': 'CD ',
#    'crest': 'https://crests.football-data.org/5530.png'},
#   'awayTeam': {'id': 9136,
#    'name': 'CF Estrela da Amadora',
#    'shortName': 'Amadora',
#    'tla': 'AMA',
#    'crest': 'https://crests.football-data.org/9136.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545735,
#   'utcDate': '2025-08-31T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 4,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 496,
#    'name': 'Rio Ave FC',
#    'shortName': 'Rio Ave',
#    'tla': 'RIO',
#    'crest': 'https://crests.football-data.org/496.png'},
#   'awayTeam': {'id': 5613,
#    'name': 'Sporting Clube de Braga',
#    'shortName': 'Braga',
#    'tla': 'SCB',
#    'crest': 'https://crests.football-data.org/5613.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 2},
#    'halfTime': {'home': 2, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545725,
#   'utcDate': '2025-09-06T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 3,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 582,
#    'name': 'GD Estoril Praia',
#    'shortName': 'Estoril Praia',
#    'tla': 'EST',
#    'crest': 'https://crests.football-data.org/582.png'},
#   'awayTeam': {'id': 5530,
#    'name': 'CD Santa Clara',
#    'shortName': 'Santa Clara',
#    'tla': 'CD ',
#    'crest': 'https://crests.football-data.org/5530.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 1},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545737,
#   'utcDate': '2025-09-12T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 5,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 7822,
#    'name': 'FC Alverca',
#    'shortName': 'Alverca',
#    'tla': 'ALV',
#    'crest': 'https://crests.football-data.org/7822.png'},
#   'awayTeam': {'id': 1049,
#    'name': 'CD Tondela',
#    'shortName': 'Tondela',
#    'tla': 'TON',
#    'crest': 'https://crests.football-data.org/1049.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 0},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545742,
#   'utcDate': '2025-09-12T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 5,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 1903,
#    'name': 'Sport Lisboa e Benfica',
#    'shortName': 'SL Benfica',
#    'tla': 'BEN',
#    'crest': 'https://crests.football-data.org/1903.png'},
#   'awayTeam': {'id': 5530,
#    'name': 'CD Santa Clara',
#    'shortName': 'Santa Clara',
#    'tla': 'CD ',
#    'crest': 'https://crests.football-data.org/5530.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 1},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545740,
#   'utcDate': '2025-09-13T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 5,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 583,
#    'name': 'Moreirense FC',
#    'shortName': 'Moreirense',
#    'tla': 'MOR',
#    'crest': 'https://crests.football-data.org/583.png'},
#   'awayTeam': {'id': 496,
#    'name': 'Rio Ave FC',
#    'shortName': 'Rio Ave',
#    'tla': 'RIO',
#    'crest': 'https://crests.football-data.org/496.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 1},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545743,
#   'utcDate': '2025-09-13T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 5,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 582,
#    'name': 'GD Estoril Praia',
#    'shortName': 'Estoril Praia',
#    'tla': 'EST',
#    'crest': 'https://crests.football-data.org/582.png'},
#   'awayTeam': {'id': 10340,
#    'name': 'AVS',
#    'shortName': 'AVS',
#    'tla': 'AVS',
#    'crest': 'https://crests.football-data.org/10340.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 1},
#    'halfTime': {'home': 2, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545744,
#   'utcDate': '2025-09-13T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 5,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 503,
#    'name': 'FC Porto',
#    'shortName': 'Porto',
#    'tla': 'FCP',
#    'crest': 'https://crests.football-data.org/503.png'},
#   'awayTeam': {'id': 5529,
#    'name': 'CD Nacional',
#    'shortName': 'CD Nacional',
#    'tla': 'CDN',
#    'crest': 'https://crests.football-data.org/5529.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 0},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545739,
#   'utcDate': '2025-09-13T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 5,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5531,
#    'name': 'FC Famalicão',
#    'shortName': 'Famalicão',
#    'tla': 'FAM',
#    'crest': 'https://crests.football-data.org/5531.png'},
#   'awayTeam': {'id': 498,
#    'name': 'Sporting Clube de Portugal',
#    'shortName': 'Sporting CP',
#    'tla': 'SPO',
#    'crest': 'https://crests.football-data.org/498.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 2},
#    'halfTime': {'home': 1, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545736,
#   'utcDate': '2025-09-14T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 5,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 9136,
#    'name': 'CF Estrela da Amadora',
#    'shortName': 'Amadora',
#    'tla': 'AMA',
#    'crest': 'https://crests.football-data.org/9136.png'},
#   'awayTeam': {'id': 5543,
#    'name': 'Vitória SC',
#    'shortName': 'Vitória SC',
#    'tla': 'GUI',
#    'crest': 'https://crests.football-data.org/5543.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 2},
#    'halfTime': {'home': 0, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
# ...
#   'status': 'FINISHED',
#   'matchday': 33,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-11T23:24:13Z',
#   'homeTeam': {'id': 1049,
#    'name': 'CD Tondela',
#    'shortName': 'Tondela',
#    'tla': 'TON',
#    'crest': 'https://crests.football-data.org/1049.png'},
#   'awayTeam': {'id': 583,
#    'name': 'Moreirense FC',
#    'shortName': 'Moreirense',
#    'tla': 'MOR',
#    'crest': 'https://crests.football-data.org/583.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 0},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': [{'id': 57144,
#     'name': 'Ricardo Baixinho',
#     'type': 'REFEREE',
#     'nationality': 'Portugal'}]},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545992,
#   'utcDate': '2026-05-11T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 33,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 9136,
#    'name': 'CF Estrela da Amadora',
#    'shortName': 'Amadora',
#    'tla': 'AMA',
#    'crest': 'https://crests.football-data.org/9136.png'},
#   'awayTeam': {'id': 5531,
#    'name': 'FC Famalicão',
#    'shortName': 'Famalicão',
#    'tla': 'FAM',
#    'crest': 'https://crests.football-data.org/5531.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': [{'id': 37812,
#     'name': 'Fábio Veríssimo',
#     'type': 'REFEREE',
#     'nationality': 'Portugal'}]},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545994,
#   'utcDate': '2026-05-11T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 33,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 496,
#    'name': 'Rio Ave FC',
#    'shortName': 'Rio Ave',
#    'tla': 'RIO',
#    'crest': 'https://crests.football-data.org/496.png'},
#   'awayTeam': {'id': 498,
#    'name': 'Sporting Clube de Portugal',
#    'shortName': 'Sporting CP',
#    'tla': 'SPO',
#    'crest': 'https://crests.football-data.org/498.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 4},
#    'halfTime': {'home': 1, 'away': 2}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': [{'id': 220577,
#     'name': 'João Gonçalves',
#     'type': 'REFEREE',
#     'nationality': 'Portugal'}]},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545995,
#   'utcDate': '2026-05-11T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 33,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5530,
#    'name': 'CD Santa Clara',
#    'shortName': 'Santa Clara',
#    'tla': 'CD ',
#    'crest': 'https://crests.football-data.org/5530.png'},
#   'awayTeam': {'id': 5529,
#    'name': 'CD Nacional',
#    'shortName': 'CD Nacional',
#    'tla': 'CDN',
#    'crest': 'https://crests.football-data.org/5529.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 0},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': [{'id': 220533,
#     'name': 'Hélder Carvalho',
#     'type': 'REFEREE',
#     'nationality': 'Portugal'}]},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545996,
#   'utcDate': '2026-05-11T19:15:00Z',
#   'status': 'FINISHED',
#   'matchday': 33,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 1903,
#    'name': 'Sport Lisboa e Benfica',
#    'shortName': 'SL Benfica',
#    'tla': 'BEN',
#    'crest': 'https://crests.football-data.org/1903.png'},
#   'awayTeam': {'id': 5613,
#    'name': 'Sporting Clube de Braga',
#    'shortName': 'Braga',
#    'tla': 'SCB',
#    'crest': 'https://crests.football-data.org/5613.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 2},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': [{'id': 38806,
#     'name': 'João Pinheiro',
#     'type': 'REFEREE',
#     'nationality': 'Portugal'}]},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545997,
#   'utcDate': '2026-05-16T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 583,
#    'name': 'Moreirense FC',
#    'shortName': 'Moreirense',
#    'tla': 'MOR',
#    'crest': 'https://crests.football-data.org/583.png'},
#   'awayTeam': {'id': 10340,
#    'name': 'AVS',
#    'shortName': 'AVS',
#    'tla': 'AVS',
#    'crest': 'https://crests.football-data.org/10340.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 0, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 546000,
#   'utcDate': '2026-05-16T14:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 503,
#    'name': 'FC Porto',
#    'shortName': 'Porto',
#    'tla': 'FCP',
#    'crest': 'https://crests.football-data.org/503.png'},
#   'awayTeam': {'id': 5530,
#    'name': 'CD Santa Clara',
#    'shortName': 'Santa Clara',
#    'tla': 'CD ',
#    'crest': 'https://crests.football-data.org/5530.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 546002,
#   'utcDate': '2026-05-16T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5529,
#    'name': 'CD Nacional',
#    'shortName': 'CD Nacional',
#    'tla': 'CDN',
#    'crest': 'https://crests.football-data.org/5529.png'},
#   'awayTeam': {'id': 5543,
#    'name': 'Vitória SC',
#    'shortName': 'Vitória SC',
#    'tla': 'GUI',
#    'crest': 'https://crests.football-data.org/5543.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 546003,
#   'utcDate': '2026-05-16T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 6618,
#    'name': 'Casa Pia AC',
#    'shortName': 'Casa Pia',
#    'tla': 'CAS',
#    'crest': 'https://crests.football-data.org/6618.png'},
#   'awayTeam': {'id': 496,
#    'name': 'Rio Ave FC',
#    'shortName': 'Rio Ave',
#    'tla': 'RIO',
#    'crest': 'https://crests.football-data.org/496.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 1},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 546004,
#   'utcDate': '2026-05-16T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 712,
#    'name': 'FC Arouca',
#    'shortName': 'Arouca',
#    'tla': 'FCA',
#    'crest': 'https://crests.football-data.org/712.png'},
#   'awayTeam': {'id': 1049,
#    'name': 'CD Tondela',
#    'shortName': 'Tondela',
#    'tla': 'TON',
#    'crest': 'https://crests.football-data.org/1049.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 1},
#    'halfTime': {'home': 1, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 546005,
#   'utcDate': '2026-05-16T17:00:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5613,
#    'name': 'Sporting Clube de Braga',
#    'shortName': 'Braga',
#    'tla': 'SCB',
#    'crest': 'https://crests.football-data.org/5613.png'},
#   'awayTeam': {'id': 9136,
#    'name': 'CF Estrela da Amadora',
#    'shortName': 'Amadora',
#    'tla': 'AMA',
#    'crest': 'https://crests.football-data.org/9136.png'},
#   'score': {'winner': 'DRAW',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 2, 'away': 2},
#    'halfTime': {'home': 1, 'away': 1}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545998,
#   'utcDate': '2026-05-16T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 5531,
#    'name': 'FC Famalicão',
#    'shortName': 'Famalicão',
#    'tla': 'FAM',
#    'crest': 'https://crests.football-data.org/5531.png'},
#   'awayTeam': {'id': 7822,
#    'name': 'FC Alverca',
#    'shortName': 'Alverca',
#    'tla': 'ALV',
#    'crest': 'https://crests.football-data.org/7822.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 0},
#    'halfTime': {'home': 0, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 545999,
#   'utcDate': '2026-05-16T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 498,
#    'name': 'Sporting Clube de Portugal',
#    'shortName': 'Sporting CP',
#    'tla': 'SPO',
#    'crest': 'https://crests.football-data.org/498.png'},
#   'awayTeam': {'id': 5533,
#    'name': 'Gil Vicente FC',
#    'shortName': 'Gil Vicente',
#    'tla': 'GIL',
#    'crest': 'https://crests.football-data.org/5533.png'},
#   'score': {'winner': 'HOME_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 3, 'away': 0},
#    'halfTime': {'home': 2, 'away': 0}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []},
#  {'area': {'id': 2187,
#    'name': 'Portugal',
#    'code': 'POR',
#    'flag': 'https://crests.football-data.org/765.svg'},
#   'competition': {'id': 2017,
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'type': 'LEAGUE',
#    'emblem': 'https://crests.football-data.org/PPL.png'},
#   'season': {'id': 2433,
#    'startDate': '2025-08-08',
#    'endDate': '2026-05-17',
#    'currentMatchday': 34,
#    'winner': None},
#   'id': 546001,
#   'utcDate': '2026-05-16T19:30:00Z',
#   'status': 'FINISHED',
#   'matchday': 34,
#   'stage': 'REGULAR_SEASON',
#   'group': None,
#   'lastUpdated': '2026-05-25T00:20:44Z',
#   'homeTeam': {'id': 582,
#    'name': 'GD Estoril Praia',
#    'shortName': 'Estoril Praia',
#    'tla': 'EST',
#    'crest': 'https://crests.football-data.org/582.png'},
#   'awayTeam': {'id': 1903,
#    'name': 'Sport Lisboa e Benfica',
#    'shortName': 'SL Benfica',
#    'tla': 'BEN',
#    'crest': 'https://crests.football-data.org/1903.png'},
#   'score': {'winner': 'AWAY_TEAM',
#    'duration': 'REGULAR',
#    'fullTime': {'home': 1, 'away': 3},
#    'halfTime': {'home': 0, 'away': 3}},
#   'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#   'referees': []}]

# %%
len(matches["matches"])
# Out:
# 306

# %%
type(matches["matches"])
# Out:
# list

# %%
#now use json_normalize and put it into the main code of the Portuguese League matches

json_normalize(matches["matches"])
# Out:
#          id               utcDate    status  matchday           stage group  \
# 0    545700  2025-08-08T19:15:00Z  FINISHED         1  REGULAR_SEASON  None
# 1    545706  2025-08-09T14:30:00Z  FINISHED         1  REGULAR_SEASON  None
# 2    545703  2025-08-09T19:30:00Z  FINISHED         1  REGULAR_SEASON  None
# 3    545707  2025-08-10T16:00:00Z  FINISHED         1  REGULAR_SEASON  None
# 4    545701  2025-08-10T19:30:00Z  FINISHED         1  REGULAR_SEASON  None
# ..      ...                   ...       ...       ...             ...   ...
# 301  546004  2026-05-16T17:00:00Z  FINISHED        34  REGULAR_SEASON  None
# 302  546005  2026-05-16T17:00:00Z  FINISHED        34  REGULAR_SEASON  None
# 303  545998  2026-05-16T19:30:00Z  FINISHED        34  REGULAR_SEASON  None
# 304  545999  2026-05-16T19:30:00Z  FINISHED        34  REGULAR_SEASON  None
# 305  546001  2026-05-16T19:30:00Z  FINISHED        34  REGULAR_SEASON  None
#
#               lastUpdated referees  area.id area.name  ... awayTeam.shortName  \
# 0    2026-05-25T00:20:44Z       []     2187  Portugal  ...        Sporting CP
# 1    2026-05-25T00:20:44Z       []     2187  Portugal  ...        Gil Vicente
# 2    2026-05-25T00:20:44Z       []     2187  Portugal  ...                AVS
# 3    2026-05-25T00:20:44Z       []     2187  Portugal  ...        Santa Clara
# 4    2026-05-25T00:20:44Z       []     2187  Portugal  ...            Tondela
# ..                    ...      ...      ...       ...  ...                ...
# 301  2026-05-25T00:20:44Z       []     2187  Portugal  ...            Tondela
# 302  2026-05-25T00:20:44Z       []     2187  Portugal  ...            Amadora
# 303  2026-05-25T00:20:44Z       []     2187  Portugal  ...            Alverca
# 304  2026-05-25T00:20:44Z       []     2187  Portugal  ...        Gil Vicente
# 305  2026-05-25T00:20:44Z       []     2187  Portugal  ...         SL Benfica
#
#     awayTeam.tla                              awayTeam.crest score.winner  \
# 0            SPO    https://crests.football-data.org/498.png    AWAY_TEAM
# 1            GIL   https://crests.football-data.org/5533.png    AWAY_TEAM
# 2            AVS  https://crests.football-data.org/10340.png    HOME_TEAM
# 3            CD    https://crests.football-data.org/5530.png    HOME_TEAM
# 4            TON   https://crests.football-data.org/1049.png    HOME_TEAM
# ..           ...                                         ...          ...
# 301          TON   https://crests.football-data.org/1049.png    HOME_TEAM
# 302          AMA   https://crests.football-data.org/9136.png         DRAW
# 303          ALV   https://crests.football-data.org/7822.png    HOME_TEAM
# 304          GIL   https://crests.football-data.org/5533.png    HOME_TEAM
# 305          BEN   https://crests.football-data.org/1903.png    AWAY_TEAM
#
#     score.duration score.fullTime.home score.fullTime.away  \
# 0          REGULAR                   0                   2
# 1          REGULAR                   0                   2
# 2          REGULAR                   3                   1
# 3          REGULAR                   3                   0
# 4          REGULAR                   3                   0
# ..             ...                 ...                 ...
# 301        REGULAR                   3                   1
# 302        REGULAR                   2                   2
# 303        REGULAR                   1                   0
# 304        REGULAR                   3                   0
# 305        REGULAR                   1                   3
#
#      score.halfTime.home score.halfTime.away  \
# 0                      0                   1
# 1                      0                   2
# 2                      1                   0
# 3                      2                   0
# 4                      2                   0
# ..                   ...                 ...
# 301                    1                   0
# 302                    1                   1
# 303                    0                   0
# 304                    2                   0
# 305                    0                   3
#
#                                               odds.msg
# 0    Activate Odds-Package in User-Panel to retriev...
# 1    Activate Odds-Package in User-Panel to retriev...
# 2    Activate Odds-Package in User-Panel to retriev...
# 3    Activate Odds-Package in User-Panel to retriev...
# 4    Activate Odds-Package in User-Panel to retriev...
# ..                                                 ...
# 301  Activate Odds-Package in User-Panel to retriev...
# 302  Activate Odds-Package in User-Panel to retriev...
# 303  Activate Odds-Package in User-Panel to retriev...
# 304  Activate Odds-Package in User-Panel to retriev...
# 305  Activate Odds-Package in User-Panel to retriev...
#
# [306 rows x 39 columns]

# %%
PPL_matches
# Out:
#          id               utcDate    status  matchday           stage group  \
# 0    545700  2025-08-08T19:15:00Z  FINISHED         1  REGULAR_SEASON  None
# 1    545706  2025-08-09T14:30:00Z  FINISHED         1  REGULAR_SEASON  None
# 2    545703  2025-08-09T19:30:00Z  FINISHED         1  REGULAR_SEASON  None
# 3    545707  2025-08-10T16:00:00Z  FINISHED         1  REGULAR_SEASON  None
# 4    545701  2025-08-10T19:30:00Z  FINISHED         1  REGULAR_SEASON  None
# ..      ...                   ...       ...       ...             ...   ...
# 301  546004  2026-05-16T17:00:00Z  FINISHED        34  REGULAR_SEASON  None
# 302  546005  2026-05-16T17:00:00Z  FINISHED        34  REGULAR_SEASON  None
# 303  545998  2026-05-16T19:30:00Z  FINISHED        34  REGULAR_SEASON  None
# 304  545999  2026-05-16T19:30:00Z  FINISHED        34  REGULAR_SEASON  None
# 305  546001  2026-05-16T19:30:00Z  FINISHED        34  REGULAR_SEASON  None
#
#               lastUpdated referees  area.id area.name  ... awayTeam.shortName  \
# 0    2026-05-25T00:20:44Z       []     2187  Portugal  ...        Sporting CP
# 1    2026-05-25T00:20:44Z       []     2187  Portugal  ...        Gil Vicente
# 2    2026-05-25T00:20:44Z       []     2187  Portugal  ...                AVS
# 3    2026-05-25T00:20:44Z       []     2187  Portugal  ...        Santa Clara
# 4    2026-05-25T00:20:44Z       []     2187  Portugal  ...            Tondela
# ..                    ...      ...      ...       ...  ...                ...
# 301  2026-05-25T00:20:44Z       []     2187  Portugal  ...            Tondela
# 302  2026-05-25T00:20:44Z       []     2187  Portugal  ...            Amadora
# 303  2026-05-25T00:20:44Z       []     2187  Portugal  ...            Alverca
# 304  2026-05-25T00:20:44Z       []     2187  Portugal  ...        Gil Vicente
# 305  2026-05-25T00:20:44Z       []     2187  Portugal  ...         SL Benfica
#
#     awayTeam.tla                              awayTeam.crest score.winner  \
# 0            SPO    https://crests.football-data.org/498.png    AWAY_TEAM
# 1            GIL   https://crests.football-data.org/5533.png    AWAY_TEAM
# 2            AVS  https://crests.football-data.org/10340.png    HOME_TEAM
# 3            CD    https://crests.football-data.org/5530.png    HOME_TEAM
# 4            TON   https://crests.football-data.org/1049.png    HOME_TEAM
# ..           ...                                         ...          ...
# 301          TON   https://crests.football-data.org/1049.png    HOME_TEAM
# 302          AMA   https://crests.football-data.org/9136.png         DRAW
# 303          ALV   https://crests.football-data.org/7822.png    HOME_TEAM
# 304          GIL   https://crests.football-data.org/5533.png    HOME_TEAM
# 305          BEN   https://crests.football-data.org/1903.png    AWAY_TEAM
#
#     score.duration score.fullTime.home score.fullTime.away  \
# 0          REGULAR                   0                   2
# 1          REGULAR                   0                   2
# 2          REGULAR                   3                   1
# 3          REGULAR                   3                   0
# 4          REGULAR                   3                   0
# ..             ...                 ...                 ...
# 301        REGULAR                   3                   1
# 302        REGULAR                   2                   2
# 303        REGULAR                   1                   0
# 304        REGULAR                   3                   0
# 305        REGULAR                   1                   3
#
#      score.halfTime.home score.halfTime.away  \
# 0                      0                   1
# 1                      0                   2
# 2                      1                   0
# 3                      2                   0
# 4                      2                   0
# ..                   ...                 ...
# 301                    1                   0
# 302                    1                   1
# 303                    0                   0
# 304                    2                   0
# 305                    0                   3
#
#                                               odds.msg
# 0    Activate Odds-Package in User-Panel to retriev...
# 1    Activate Odds-Package in User-Panel to retriev...
# 2    Activate Odds-Package in User-Panel to retriev...
# 3    Activate Odds-Package in User-Panel to retriev...
# 4    Activate Odds-Package in User-Panel to retriev...
# ..                                                 ...
# 301  Activate Odds-Package in User-Panel to retriev...
# 302  Activate Odds-Package in User-Panel to retriev...
# 303  Activate Odds-Package in User-Panel to retriev...
# 304  Activate Odds-Package in User-Panel to retriev...
# 305  Activate Odds-Package in User-Panel to retriev...
#
# [306 rows x 39 columns]

# %%
PPL_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      306 non-null    int64
#  1   utcDate                 306 non-null    object
#  2   status                  306 non-null    object
#  3   matchday                306 non-null    int64
#  4   stage                   306 non-null    object
#  5   group                   0 non-null      object
#  6   lastUpdated             306 non-null    object
#  7   referees                306 non-null    object
#  8   area.id                 306 non-null    int64
#  9   area.name               306 non-null    object
#  10  area.code               306 non-null    object
#  11  area.flag               306 non-null    object
#  12  competition.id          306 non-null    int64
#  13  competition.name        306 non-null    object
#  14  competition.code        306 non-null    object
#  15  competition.type        306 non-null    object
#  16  competition.emblem      306 non-null    object
#  17  season.id               306 non-null    int64
#  18  season.startDate        306 non-null    object
#  19  season.endDate          306 non-null    object
#  20  season.currentMatchday  306 non-null    int64
#  21  season.winner           0 non-null      object
#  22  homeTeam.id             306 non-null    int64
#  23  homeTeam.name           306 non-null    object
#  24  homeTeam.shortName      306 non-null    object
#  25  homeTeam.tla            306 non-null    object
#  26  homeTeam.crest          306 non-null    object
#  27  awayTeam.id             306 non-null    int64
#  28  awayTeam.name           306 non-null    object
#  29  awayTeam.shortName      306 non-null    object
#  30  awayTeam.tla            306 non-null    object
#  31  awayTeam.crest          306 non-null    object
#  32  score.winner            306 non-null    object
#  33  score.duration          306 non-null    object
#  34  score.fullTime.home     306 non-null    int64
#  35  score.fullTime.away     306 non-null    int64
#  36  score.halfTime.home     306 non-null    int64
#  37  score.halfTime.away     306 non-null    int64
#  38  odds.msg                306 non-null    object
# dtypes: int64(12), object(27)
# memory usage: 93.4+ KB

# %%
#holding on wins at home (win at HT and FT)

first_metric = PPL_matches[(PPL_matches["score.halfTime.home"] > PPL_matches["score.halfTime.away"]) & (PPL_matches["score.winner"] == "HOME_TEAM")]

# %%
first_metric
# Out:
#          id               utcDate    status  matchday           stage group  \
# 2    545703  2025-08-09T19:30:00Z  FINISHED         1  REGULAR_SEASON  None
# 3    545707  2025-08-10T16:00:00Z  FINISHED         1  REGULAR_SEASON  None
# 4    545701  2025-08-10T19:30:00Z  FINISHED         1  REGULAR_SEASON  None
# 7    545708  2025-08-11T19:45:00Z  FINISHED         1  REGULAR_SEASON  None
# 15   545715  2025-08-17T19:30:00Z  FINISHED         2  REGULAR_SEASON  None
# ..      ...                   ...       ...       ...             ...   ...
# 288  545991  2026-05-10T17:00:00Z  FINISHED        33  REGULAR_SEASON  None
# 292  545990  2026-05-11T19:15:00Z  FINISHED        33  REGULAR_SEASON  None
# 295  545995  2026-05-11T19:15:00Z  FINISHED        33  REGULAR_SEASON  None
# 301  546004  2026-05-16T17:00:00Z  FINISHED        34  REGULAR_SEASON  None
# 304  545999  2026-05-16T19:30:00Z  FINISHED        34  REGULAR_SEASON  None
#
#               lastUpdated                                           referees  \
# 2    2026-05-25T00:20:44Z                                                 []
# 3    2026-05-25T00:20:44Z                                                 []
# 4    2026-05-25T00:20:44Z                                                 []
# 7    2026-05-25T00:20:44Z                                                 []
# 15   2026-05-25T00:20:44Z                                                 []
# ..                    ...                                                ...
# 288  2026-05-25T00:20:44Z  [{'id': 40454, 'name': 'Carlos Macedo', 'type'...
# 292  2026-05-11T23:24:13Z  [{'id': 57144, 'name': 'Ricardo Baixinho', 'ty...
# 295  2026-05-25T00:20:44Z  [{'id': 220533, 'name': 'Hélder Carvalho', 'ty...
# 301  2026-05-25T00:20:44Z                                                 []
# 304  2026-05-25T00:20:44Z                                                 []
#
#      area.id area.name  ... awayTeam.shortName awayTeam.tla  \
# 2       2187  Portugal  ...                AVS          AVS
# 3       2187  Portugal  ...        Santa Clara          CD
# 4       2187  Portugal  ...            Tondela          TON
# 7       2187  Portugal  ...         Vitória SC          GUI
# 15      2187  Portugal  ...             Arouca          FCA
# ..       ...       ...  ...                ...          ...
# 288     2187  Portugal  ...              Porto          FCP
# 292     2187  Portugal  ...         Moreirense          MOR
# 295     2187  Portugal  ...        CD Nacional          CDN
# 301     2187  Portugal  ...            Tondela          TON
# 304     2187  Portugal  ...        Gil Vicente          GIL
#
#                                  awayTeam.crest score.winner score.duration  \
# 2    https://crests.football-data.org/10340.png    HOME_TEAM        REGULAR
# 3     https://crests.football-data.org/5530.png    HOME_TEAM        REGULAR
# 4     https://crests.football-data.org/1049.png    HOME_TEAM        REGULAR
# 7     https://crests.football-data.org/5543.png    HOME_TEAM        REGULAR
# 15     https://crests.football-data.org/712.png    HOME_TEAM        REGULAR
# ..                                          ...          ...            ...
# 288    https://crests.football-data.org/503.png    HOME_TEAM        REGULAR
# 292    https://crests.football-data.org/583.png    HOME_TEAM        REGULAR
# 295   https://crests.football-data.org/5529.png    HOME_TEAM        REGULAR
# 301   https://crests.football-data.org/1049.png    HOME_TEAM        REGULAR
# 304   https://crests.football-data.org/5533.png    HOME_TEAM        REGULAR
#
#     score.fullTime.home score.fullTime.away  score.halfTime.home  \
# 2                     3                   1                    1
# 3                     3                   0                    2
# 4                     3                   0                    2
# 7                     3                   0                    2
# 15                    6                   0                    3
# ..                  ...                 ...                  ...
# 288                   3                   1                    1
# 292                   2                   0                    1
# 295                   2                   0                    1
# 301                   3                   1                    1
# 304                   3                   0                    2
#
#     score.halfTime.away                                           odds.msg
# 2                     0  Activate Odds-Package in User-Panel to retriev...
# 3                     0  Activate Odds-Package in User-Panel to retriev...
# 4                     0  Activate Odds-Package in User-Panel to retriev...
# 7                     0  Activate Odds-Package in User-Panel to retriev...
# 15                    0  Activate Odds-Package in User-Panel to retriev...
# ..                  ...                                                ...
# 288                   0  Activate Odds-Package in User-Panel to retriev...
# 292                   0  Activate Odds-Package in User-Panel to retriev...
# 295                   0  Activate Odds-Package in User-Panel to retriev...
# 301                   0  Activate Odds-Package in User-Panel to retriev...
# 304                   0  Activate Odds-Package in User-Panel to retriev...
#
# [73 rows x 39 columns]

# %%
# show what we really want
first_metric["homeTeam.name"].value_counts()
# Out:
# homeTeam.name
# FC Porto                      11
# Sport Lisboa e Benfica        10
# Sporting Clube de Portugal     9
# Sporting Clube de Braga        7
# Gil Vicente FC                 5
# FC Famalicão                   5
# CD Santa Clara                 3
# FC Alverca                     3
# GD Estoril Praia               3
# CF Estrela da Amadora          3
# FC Arouca                      2
# Rio Ave FC                     2
# Vitória SC                     2
# CD Tondela                     2
# CD Nacional                    2
# Casa Pia AC                    2
# Moreirense FC                  1
# AVS                            1
# Name: count, dtype: int64

# %% [markdown]
# What we really want to see is the % of wins at HT that ended on a win at FT

# %%
#check, first, the amount of times that teams were winning at HT

first_metric_final = PPL_matches[PPL_matches["score.halfTime.home"] > PPL_matches["score.halfTime.away"]]
first_metric_final["homeTeam.name"].value_counts()
# Out:
# homeTeam.name
# FC Porto                      12
# Sport Lisboa e Benfica        11
# Sporting Clube de Portugal    10
# Sporting Clube de Braga        9
# Casa Pia AC                    6
# Gil Vicente FC                 6
# FC Famalicão                   5
# FC Arouca                      5
# FC Alverca                     5
# GD Estoril Praia               5
# CF Estrela da Amadora          4
# Rio Ave FC                     4
# CD Nacional                    3
# CD Santa Clara                 3
# Vitória SC                     2
# AVS                            2
# CD Tondela                     2
# Moreirense FC                  2
# Name: count, dtype: int64

# %%
#Now see how many of those times ended up on winning at FT and put it on %

ab = (first_metric["homeTeam.name"].value_counts() / first_metric_final["homeTeam.name"].value_counts() * 100).round(1)
ab.sort_values(ascending=False)
# Out:
# homeTeam.name
# CD Tondela                    100.0
# CD Santa Clara                100.0
# FC Famalicão                  100.0
# Vitória SC                    100.0
# FC Porto                       91.7
# Sport Lisboa e Benfica         90.9
# Sporting Clube de Portugal     90.0
# Gil Vicente FC                 83.3
# Sporting Clube de Braga        77.8
# CF Estrela da Amadora          75.0
# CD Nacional                    66.7
# FC Alverca                     60.0
# GD Estoril Praia               60.0
# AVS                            50.0
# Rio Ave FC                     50.0
# Moreirense FC                  50.0
# FC Arouca                      40.0
# Casa Pia AC                    33.3
# Name: count, dtype: float64
